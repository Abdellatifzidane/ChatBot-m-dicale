# %%
import os
import json
import boto3
import time

# === CONFIGURATION ===
FOLDER_PATH = "./notices_txt"
OUTPUT_FILE = "embeddings.json"
REGION = "us-east-1"
MODEL_ID = "amazon.titan-embed-text-v2:0"
DELAY = 0.5
LIMIT = 200  # ✅ Limite du nombre de fichiers à traiter

# === INIT CLIENT ===
client = boto3.client("bedrock-runtime", region_name=REGION)

# === FONCTION POUR VECTORISER UN TEXTE ===
def get_embedding(text):
    body = { "inputText": text }
    response = client.invoke_model(
        modelId=MODEL_ID,
        body=json.dumps(body),
        contentType="application/json"
    )
    response_body = json.loads(response['body'].read())
    return response_body['embedding']

# === TRAITEMENT LIMITÉ À 200 FICHIERS ===
embeddings = {}
file_count = 0

for filename in os.listdir(FOLDER_PATH):
    if file_count >= LIMIT:
        break

    if filename.endswith(".txt"):
        filepath = os.path.join(FOLDER_PATH, filename)
        with open(filepath, "r", encoding="utf-8") as file:
            content = file.read().strip()

            if not content:
                print(f"⚠️ Fichier vide ignoré : {filename}")
                continue

            try:
                print(f"🔄 Vectorisation : {filename}")
                vector = get_embedding(content)
                embeddings[filename] = vector
                file_count += 1
                time.sleep(DELAY)
            except Exception as e:
                print(f"❌ Erreur sur {filename} : {e}")

# === SAUVEGARDE ===
with open(OUTPUT_FILE, "w", encoding="utf-8") as out_file:
    json.dump(embeddings, out_file)

print(f"✅ {file_count} fichiers vectorisés. Résultats dans {OUTPUT_FILE}")
# Out:
# 🔄 Vectorisation : ABACAVIR VIATRIS 300 mg.txt
# ❌ Erreur sur ABACAVIR VIATRIS 300 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8693
# 🔄 Vectorisation : ABACAVIR-LAMIVUDINE BIOGARAN 600 mg-300 mg.txt
# ❌ Erreur sur ABACAVIR-LAMIVUDINE BIOGARAN 600 mg-300 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 9044
# 🔄 Vectorisation : ABACAVIR-LAMIVUDINE SANDOZ 600 mg-300 mg.txt
# ❌ Erreur sur ABACAVIR-LAMIVUDINE SANDOZ 600 mg-300 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8757
# 🔄 Vectorisation : ABACAVIR-LAMIVUDINE VIATRIS 600 mg-300 mg.txt
# ❌ Erreur sur ABACAVIR-LAMIVUDINE VIATRIS 600 mg-300 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 9319
# 🔄 Vectorisation : ABACAVIR-LAMIVUDINE ZENTIVA 600 mg-300 mg.txt
# ❌ Erreur sur ABACAVIR-LAMIVUDINE ZENTIVA 600 mg-300 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8774
# 🔄 Vectorisation : ABACAVIR-LAMIVUDINE-ZIDOVUDINE VIATRIS 300 mg-150 mg-300 mg.txt
# ❌ Erreur sur ABACAVIR-LAMIVUDINE-ZIDOVUDINE VIATRIS 300 mg-150 mg-300 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 11087
# 🔄 Vectorisation : ABASAGLAR 100 unités-ml.txt
# 🔄 Vectorisation : ABECMA 260 - 500 x 1 000 000 cellules.txt
# 🔄 Vectorisation : ABEVMY 25 mg-mL.txt
# 🔄 Vectorisation : ABILIFY 1 mg-mL.txt
# 🔄 Vectorisation : ABILIFY 10 mg.txt
# 🔄 Vectorisation : ABILIFY 15 mg.txt
# 🔄 Vectorisation : ABILIFY 5 mg.txt
# 🔄 Vectorisation : ABILIFY MAINTENA 300 mg.txt
# 🔄 Vectorisation : ABILIFY MAINTENA 400 mg.txt
# 🔄 Vectorisation : ABIRATERONE ACCORD 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE ACETATE ZYDUS 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE ARROW 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE BIOGARAN 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE CRISTERS 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE EG 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE EVOLUGEN 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE KRKA 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE MYLAN 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE SANDOZ 1000 mg.txt
# 🔄 Vectorisation : ABIRATERONE SANDOZ 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE TEVA 500 mg.txt
# 🔄 Vectorisation : ABIRATERONE ZENTIVA 500 mg.txt
# 🔄 Vectorisation : ABRAXANE 5 mg-mL.txt
# 🔄 Vectorisation : ABSTRAL 100 microgrammes.txt
# ❌ Erreur sur ABSTRAL 100 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8606
# 🔄 Vectorisation : ABSTRAL 200 microgrammes.txt
# ❌ Erreur sur ABSTRAL 200 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8612
# 🔄 Vectorisation : ABSTRAL 300 microgrammes.txt
# ❌ Erreur sur ABSTRAL 300 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8606
# 🔄 Vectorisation : ABSTRAL 400 microgrammes.txt
# ❌ Erreur sur ABSTRAL 400 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8611
# 🔄 Vectorisation : ABSTRAL 600 microgrammes.txt
# ❌ Erreur sur ABSTRAL 600 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8597
# 🔄 Vectorisation : ABSTRAL 800 microgrammes.txt
# ❌ Erreur sur ABSTRAL 800 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 8610
# 🔄 Vectorisation : ACAMPROSATE VIATRIS 333 mg.txt
# 🔄 Vectorisation : ACARBOSE ARROW 100 mg.txt
# 🔄 Vectorisation : ACARBOSE ARROW 50 mg.txt
# 🔄 Vectorisation : ACARBOSE BIOGARAN 100 mg.txt
# 🔄 Vectorisation : ACARBOSE BIOGARAN 50 mg.txt
# 🔄 Vectorisation : ACARBOSE EG 100 mg.txt
# 🔄 Vectorisation : ACARBOSE EG 50 mg.txt
# 🔄 Vectorisation : ACARBOSE SANDOZ 100 mg.txt
# 🔄 Vectorisation : ACARBOSE SANDOZ 50 mg.txt
# 🔄 Vectorisation : ACARBOSE VIATRIS 100 mg.txt
# 🔄 Vectorisation : ACARBOSE VIATRIS 50 mg.txt
# 🔄 Vectorisation : ACARBOSE ZENTIVA 100 mg.txt
# 🔄 Vectorisation : ACARBOSE ZENTIVA 50 mg.txt
# 🔄 Vectorisation : ACCOFIL 30 MU-0.5 ml.txt
# 🔄 Vectorisation : ACEBUTOLOL ALMUS 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL ARROW LAB 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL ARROW LAB 400 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL BIOGARAN 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL BIOGARAN 400 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL CRISTERS 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL EG 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL EG 400 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL SANDOZ 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL SANDOZ 400 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL TEVA 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL TEVA 400 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL VIATRIS 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL VIATRIS 400 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL ZYDUS 200 mg.txt
# 🔄 Vectorisation : ACEBUTOLOL ZYDUS 400 mg.txt
# 🔄 Vectorisation : ACECLOFENAC ACCORD 100 mg.txt
# 🔄 Vectorisation : ACETATE DE CYPROTERONE ARROW 100 mg.txt
# 🔄 Vectorisation : ACETATE DE CYPROTERONE ARROW 50 mg.txt
# 🔄 Vectorisation : ACETATE DE TERLIPRESSINE EVER PHARMA 0.2 mg-ml.txt
# 🔄 Vectorisation : ACICLOVIR AGEPHA 30 mg-g.txt
# 🔄 Vectorisation : ACICLOVIR ALMUS 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR ALMUS 5 %.txt
# 🔄 Vectorisation : ACICLOVIR ARROW 800 mg.txt
# 🔄 Vectorisation : ACICLOVIR ARROW GENERIQUES 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR BIOGARAN 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR BIOGARAN 800 mg.txt
# 🔄 Vectorisation : ACICLOVIR CRISTERS 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR EG 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR EG 800 mg.txt
# 🔄 Vectorisation : ACICLOVIR HIKMA 250 mg.txt
# 🔄 Vectorisation : ACICLOVIR HIKMA 500 mg.txt
# 🔄 Vectorisation : ACICLOVIR SANDOZ CONSEIL 5 %.txt
# 🔄 Vectorisation : ACICLOVIR TEVA 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR TEVA 800 mg.txt
# 🔄 Vectorisation : ACICLOVIR VIATRIS 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR VIATRIS 250 mg.txt
# 🔄 Vectorisation : ACICLOVIR VIATRIS 500 mg.txt
# 🔄 Vectorisation : ACICLOVIR VIATRIS 800 mg.txt
# 🔄 Vectorisation : ACICLOVIR ZENTIVA 200 mg.txt
# 🔄 Vectorisation : ACICLOVIR ZYDUS 200 mg.txt
# 🔄 Vectorisation : ACIDE ACETYLSALICYLIQUE PANPHARMA 500 mg.txt
# 🔄 Vectorisation : ACIDE ACETYLSALICYLIQUE VIATRIS 100 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE ARROW LAB 70 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE BIOGARAN 70 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE CRISTERS 70 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE EG 70 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE TEVA SANTE 70 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE VIATRIS 70 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE ZENTIVA 70 mg.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) CRISTERS 70 mg-2800 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) CRISTERS 70 mg-5600 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) EG 70 mg-2800 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) EG 70 mg-5600 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) EVOLUGEN 70 mg-2800 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) EVOLUGEN 70 mg-5600 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) ZENTIVA 70 mg-2 800 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-CHOLECALCIFEROL (VITAMINE D3) ZENTIVA 70 mg-5 600 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-VITAMINE D3 ARROW 70 mg-2 800 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-VITAMINE D3 ARROW 70 mg-5 600 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-VITAMINE D3 TEVA SANTE 70 mg-2800 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-VITAMINE D3 TEVA SANTE 70 mg-5600 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-VITAMINE D3 VIATRIS 70 mg-2800 UI.txt
# 🔄 Vectorisation : ACIDE ALENDRONIQUE-VITAMINE D3 VIATRIS 70 mg-5 600 UI.txt
# 🔄 Vectorisation : ACIDE CARGLUMIQUE TILLOMED 200 mg.txt
# 🔄 Vectorisation : ACIDE CARGLUMIQUE WAYMADE 200 mg.txt
# 🔄 Vectorisation : ACIDE FOLIQUE VIATRIS 5 mg.txt
# 🔄 Vectorisation : ACIDE FUSIDIQUE SANDOZ 2 %.txt
# 🔄 Vectorisation : ACIDE GADOTERIQUE GUERBET 0.5 mmol-mL.txt
# 🔄 Vectorisation : ACIDE TRANEXAMIQUE ACCORD 0.5 g-5 mL.txt
# 🔄 Vectorisation : ACIDE TRANEXAMIQUE AGUETTANT 0.5 g-5 mL.txt
# 🔄 Vectorisation : ACIDE TRANEXAMIQUE ARROW 0.5 g-5 ml I.V..txt
# 🔄 Vectorisation : ACIDE TRANEXAMIQUE VIATRIS 0.5 g-5 mL.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE ARROW 250 mg.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE ARROW 500 mg.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE BIOGARAN 250 mg.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE BIOGARAN 500 mg.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE TEVA 250 mg.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE TEVA 500 mg.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE VIATRIS 250 mg.txt
# 🔄 Vectorisation : ACIDE URSODESOXYCHOLIQUE VIATRIS 500 mg.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE ALTAN 4 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE ALTAN 5 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE BIOGARAN 4 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE MEDAC 4 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE MYLAN 4 mg-5 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE SANDOZ 4 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE SANDOZ 5 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE VIATRIS 4 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE VIATRIS 5 mg-100 ml.txt
# 🔄 Vectorisation : ACIDE ZOLEDRONIQUE ZENTIVA LAB 4 mg-100 ml.txt
# 🔄 Vectorisation : ACLASTA 5 mg.txt
# 🔄 Vectorisation : ACLOTINE 100 UI-mL.txt
# 🔄 Vectorisation : ACT-HIB 10 microgrammes-0.5 mL.txt
# 🔄 Vectorisation : ACTILYSE 2 mg.txt
# 🔄 Vectorisation : ACTILYSE.txt
# ❌ Erreur sur ACTILYSE.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 10696
# 🔄 Vectorisation : ACTIQ 1200 microgrammes.txt
# ❌ Erreur sur ACTIQ 1200 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 11337
# 🔄 Vectorisation : ACTIQ 1600 microgrammes.txt
# ❌ Erreur sur ACTIQ 1600 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 11344
# 🔄 Vectorisation : ACTIQ 200 microgrammes.txt
# ❌ Erreur sur ACTIQ 200 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 11327
# 🔄 Vectorisation : ACTIQ 400 microgrammes.txt
# ❌ Erreur sur ACTIQ 400 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 11324
# 🔄 Vectorisation : ACTIQ 600 microgrammes.txt
# ❌ Erreur sur ACTIQ 600 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 11328
# 🔄 Vectorisation : ACTIQ 800 microgrammes.txt
# ❌ Erreur sur ACTIQ 800 microgrammes.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 11320
# 🔄 Vectorisation : ACTISKENAN 1 mg.txt
# ❌ Erreur sur ACTISKENAN 1 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 9731
# 🔄 Vectorisation : ACTISKENAN 10 mg.txt
# 🔄 Vectorisation : ACTISKENAN 2,5 mg.txt
# ❌ Erreur sur ACTISKENAN 2,5 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 9781
# 🔄 Vectorisation : ACTISKENAN 20 mg.txt
# 🔄 Vectorisation : ACTISKENAN 30 mg.txt
# 🔄 Vectorisation : ACTISKENAN 5 mg.txt
# 🔄 Vectorisation : ACTONEL 30 mg.txt
# 🔄 Vectorisation : ACTONEL 35 mg.txt
# 🔄 Vectorisation : ACTONEL 5 mg.txt
# 🔄 Vectorisation : ACTONEL 75 mg.txt
# 🔄 Vectorisation : ACTONELCOMBI 35 mg + 1000 mg-880 UI.txt
# 🔄 Vectorisation : ACTRAPID 100 unités internationales-ml.txt
# 🔄 Vectorisation : ACTRAPID PENFILL 100 unités internationales-ml.txt
# 🔄 Vectorisation : ACUILIX 20 mg-12,5 mg.txt
# 🔄 Vectorisation : ACUITEL 20 mg.txt
# 🔄 Vectorisation : ACUITEL 5 mg.txt
# 🔄 Vectorisation : ACULAR 0.5 %.txt
# 🔄 Vectorisation : ACUPAN 20 mg-2 mL.txt
# 🔄 Vectorisation : ADCETRIS 50 mg.txt
# 🔄 Vectorisation : ADCIRCA 20 mg.txt
# 🔄 Vectorisation : ADEMPAS 0.5 mg.txt
# 🔄 Vectorisation : ADEMPAS 1 mg.txt
# 🔄 Vectorisation : ADEMPAS 1,5 mg.txt
# 🔄 Vectorisation : ADEMPAS 2 mg.txt
# 🔄 Vectorisation : ADEMPAS 2,5 mg.txt
# 🔄 Vectorisation : ADENOSCAN 30 mg-10 mL.txt
# 🔄 Vectorisation : ADENOSINE HIKMA 6 mg-2 mL.txt
# 🔄 Vectorisation : ADENOSINE MEDISOL 6 mg-2 ml.txt
# 🔄 Vectorisation : ADENURIC 120 mg.txt
# 🔄 Vectorisation : ADENURIC 80 mg.txt
# 🔄 Vectorisation : ADEPAL.txt
# ❌ Erreur sur ADEPAL.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 13156
# 🔄 Vectorisation : ADIAZINE 500 mg.txt
# 🔄 Vectorisation : ADOPORT 0.5 mg.txt
# 🔄 Vectorisation : ADOPORT 1 mg.txt
# 🔄 Vectorisation : ADOPORT 2 mg.txt
# 🔄 Vectorisation : ADOPORT 5 mg.txt
# 🔄 Vectorisation : ADRENALINE AGUETTANT 0.1 mg-mL sans sulfite.txt
# 🔄 Vectorisation : ADRENALINE AGUETTANT 1 mg-mL SANS SULFITE.txt
# 🔄 Vectorisation : ADRENALINE AGUETTANT 1 mg-ml.txt
# 🔄 Vectorisation : ADRENALINE RENAUDIN 0.25 mg-mL.txt
# 🔄 Vectorisation : ADRENALINE RENAUDIN 0.50 mg-mL.txt
# 🔄 Vectorisation : ADRENALINE RENAUDIN 1 mg-mL.txt
# 🔄 Vectorisation : ADRIBLASTINE 10 mg.txt
# 🔄 Vectorisation : ADRIBLASTINE 50 mg.txt
# 🔄 Vectorisation : ADROVANCE 70 mg-2800 UI.txt
# 🔄 Vectorisation : ADROVANCE 70 mg-5600 UI.txt
# 🔄 Vectorisation : ADVAGRAF 0.5 mg.txt
# 🔄 Vectorisation : ADVAGRAF 1 mg.txt
# 🔄 Vectorisation : ADVAGRAF 3 mg.txt
# 🔄 Vectorisation : ADVAGRAF 5 mg.txt
# 🔄 Vectorisation : ADVATE 1000 UI.txt
# 🔄 Vectorisation : ADVATE 1500 UI.txt
# 🔄 Vectorisation : ADVATE 2000 UI.txt
# 🔄 Vectorisation : ADVATE 250 UI.txt
# 🔄 Vectorisation : ADVATE 3000 UI.txt
# 🔄 Vectorisation : ADVATE 500 UI.txt
# 🔄 Vectorisation : AERRANE.txt
# 🔄 Vectorisation : AFINITOR 10 mg.txt
# 🔄 Vectorisation : AFINITOR 2,5 mg.txt
# 🔄 Vectorisation : AFINITOR 5 mg.txt
# 🔄 Vectorisation : AFLAVIS 1 mg-mL.txt
# 🔄 Vectorisation : AFSTYLA 1000 UI.txt
# 🔄 Vectorisation : AFSTYLA 1500 UI.txt
# 🔄 Vectorisation : AFSTYLA 2000 UI.txt
# 🔄 Vectorisation : AFSTYLA 250 UI.txt
# 🔄 Vectorisation : AFSTYLA 2500 UI.txt
# 🔄 Vectorisation : AFSTYLA 3000 UI.txt
# 🔄 Vectorisation : AFSTYLA 500 UI.txt
# 🔄 Vectorisation : AGOMELATINE BIOGARAN 25 mg.txt
# 🔄 Vectorisation : AGOMELATINE EG 25 mg.txt
# 🔄 Vectorisation : AGOMELATINE VIATRIS 25 mg.txt
# ❌ Erreur sur AGOMELATINE VIATRIS 25 mg.txt : An error occurred (ValidationException) when calling the InvokeModel operation: 400 Bad Request: Too many input tokens. Max input tokens: 8192, request input token count: 12159
# 🔄 Vectorisation : AGOMELATINE ZENTIVA 25 mg.txt
# ✅ 200 fichiers vectorisés. Résultats dans embeddings.json
